# %%
secret_word = "giraffe"
guess = " "
guess_count = 0
guess_limit = 3
out_of_guesses = False 

while guess != secret_word:
    
    guess = input("Enter guess: ")
    guess_count += 1 
    

print("You win")
# Out:
# Enter guess:
# Enter guess: sd
# Enter guess: sdfa
# Enter guess: asg
# Enter guess: giraffe
# You win

# %%
secret_word = "giraffe"
guess = " "
guess_count = 0
guess_limit = 3
out_of_guesses = False 

while guess != secret_word and not(out_of_guesses):
    if guess_count < guess_limit:
        
        guess = input("Enter guess: ")
        guess_count += 1 
    else: 
        out_of_guesses = True 
    
if out_of_guesses:
    print("Out of Guesses, You Lose!")
else:
    print("You win")
# Out:
# Enter guess: asdf
# Enter guess: asdf
# Enter guess: asdf
# Out of Guesses, You Lose!

# %%
secret_word = "giraffe"
guess = " "
guess_count = 0
guess_limit = 3
out_of_guesses = False 

while guess != secret_word and not(out_of_guesses):
    if guess_count < guess_limit:
        
        guess = input("Enter guess: ")
        guess_count += 1 
    else: 
        out_of_guesses = True 
    
if out_of_guesses:
    print("Out of Guesses, You Lose!")
else:
    print("You win")
# Out:
# Enter guess: sd
# Enter guess: f
# Enter guess: giraffe
# You win

# %%
##For Loops

# %%
for letter in "Düldüller":
    print(letter)
# Out:
# D
# ü
# l
# d
# ü
# l
# l
# e
# r

# %%
friends = ["Jim","Karen","Dalyo"]
for a in friends:
    print(a)
# Out:
# Jim
# Karen
# Dalyo

# %%
friends = ["Jim","Karen","Dalyo"]

for a in range(len(friends)):
    print(friends[a])
# Out:
# Jim
# Karen
# Dalyo

# %%
friends = ["Jim","Karen","Dalyo"]

for a in range(5):
    if a == 0:
        print("first")
    else:
        print("other")
# Out:
# first
# other
# other
# other
# other

# %%
275*2*5

#Rukiye teyezmler
# Out:
# 2750

# %%
275*1*8 #nurhan teyze
# Out:
# 2200

# %%
275*1*3 #muhammed abi
# Out:
# 825

# %%
825*2 #anneannemler
# Out:
# 1650

# %%
2750 + 2200 + 825 + 1650
# Out:
# 7425

# %%
22000-7425 #bizim ödediğimiz
# Out:
# 14575

# %%
14575-8350 #bizden kalan
# Out:
# 6225

# %%
6225 + 1650 #total ödememiz gereken nakit
# Out:
# 7875

# %%
# Out:
# 6125

# %%
# Out:
# 5775

# %%
# Out:
#   File "<ipython-input-33-32bdbcbdd33f>", line 1
#     22000 %% 10
#            ^
# SyntaxError: invalid syntax

# %%
def raise_to_power(base_num, pow_num):
    result = 1
    for index in range(pow_num):
        result = result * base_num
    return result

# %%
raise_to_power(123,1234)
# Out:
# ...

# %%
dudesdudesdudes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c155b6b9aea2> in <module>
# ----> 1 dudesdudesdudes
#
# NameError: name 'dudesdudesdudes' is not defined

# %%
range(...)
# Out:
# range(0, ...)

# %%
len(str(...))
# Out:
# 2579

# %%
number_grid = [[1,2,3],[4,5,6],[7,8,9],[0]]

print(number_grid[3][0])
# Out:
# 0

# %%
number_grid = [
    [1,2,3],
    [4,5,6],
    [7,8,9],
    [0]
]

for row in number_grid:
    for col in row:
        
    print(row)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
# [0]
